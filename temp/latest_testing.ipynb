# %%
# %sh
curl -I https://www.google.com

# %%
# %sh
curl -I https://oregon.cloud.databricks.com

# %%
spark.sql("USE CATALOG commodity")

# %%
# %sql
SELECT current_catalog(), current_schema();

# %%
# %sql
SELECT 1;

# %%
# %sh
curl -v --max-time 10 https://dbc-fd7b00f3-7a6d.cloud.databricks.com/api/2.1/unity-catalog/catalogs

# %%
# %sh
ping -c 3 10.53.215.134

# %%
# %sh
nc -zv -w 5 10.53.215.134 443

# %%
# %sh
openssl s_client -connect 10.53.215.134:443 -servername dbc-fd7b00f3-7a6d.cloud.databricks.com < /dev/null 2>&1 | head -30

# %%
# %sh
nslookup dbc-fd7b00f3-7a6d.cloud.databricks.com 8.8.8.8

# %%
# %sh
grep databricks /etc/hosts

# %%
# %sh
ping -c 3 10.53.166.205

# %%
# %sh
curl -I https://10.53.166.205 --connect-timeout 5
